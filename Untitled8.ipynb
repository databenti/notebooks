# %%
import pandas as pd

# %%
import json
import pandas as pd
data = json.load(open('data.json', encoding="utf8"))

# %%
print(data)
# Out:
# {'selected_filters': [{'items': [{'name': 'White Wine', 'id': 2, 'background_image': {'variations': {'small': '//images.vivino.com/backgrounds/winetypes/thumbs/v6qEDIiuS3Kf7d9opfXwDg_932x810.jpg'}, 'location': '//images.vivino.com/backgrounds/winetypes/v6qEDIiuS3Kf7d9opfXwDg.jpg'}}], 'type': 'wine_type_ids'}], 'e': 'eJzLLbI10jNVy83MszVQy02ssDU0MjVQS660TSpSS7Z1CvJRK7A1NABKJduq5ScBsa1aeUl0rK0RAN9eEIg=', 'explore_vintage': {'records': [{'vintage': {'name': 'Olmèra 2013', 'id': 7431976, 'statistics': {'ratings_count': 42, 'ratings_average': 4.4, 'labels_count': 170}, 'wine': {'type_id': 2, 'style': {'body': 3, 'name': 'Northern Italy White', 'id': 131, 'country': {'name': 'Italy', 'users_count': 2377978, 'currency': {'name': 'Euros', 'prefix': '€', 'code': 'EUR', 'suffix': None}, 'most_used_grapes': [{'wines_count': 77926, 'name': 'Sangiovese', 'id': 16, 'seo_name': 'sangiovese', 'has_detailed_info': True}, {'wines_count': 333522, 'name': 'Merlot', 'id': 10, 'seo_name': 'merlot', 'has_de
# ...

# %%
df = pd.DataFrame(data['items'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-1fa728a748a5> in <module>()
# ----> 1 df = pd.DataFrame(data['items'])
#
# KeyError: 'items'

# %%
df
# Out:
#                                                items           type
# 0  [{'name': 'White Wine', 'id': 2, 'background_i...  wine_type_ids
